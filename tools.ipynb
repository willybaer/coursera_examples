# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Wilhelm Dewald**
# I want to be Data Super Hero

# %% [markdown]
# *I am interested in data science because data is the new oil of our future economy*

# %% [markdown]
# ### The code below returns the correct number of characters in a given string

# %%
def num_chars(s):
    return "the string \"{}\" has {} chars in total".format(s, len(s))

num_chars("Data Science")
# Out:
# 'the string "Data Science" has 12 chars in total'

# %% [markdown]
# - One
# - Two
#
# | Header      | Header      |
# | ----------- | ----------- |
# | Test1       | test2       |
# | Text        | Text        |
#
# > Coursera is super cool.
